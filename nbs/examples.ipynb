# %% [markdown]
# # STATISTICS EXERCISE
# > Here you will find statistics exercises with their own module.

# %%
#| hide
from importlib.machinery import SourceFileLoader
import numpy as np  # Importar numpy
import matplotlib.pyplot as plt  # Importar matplotlib para los gráficos
import seaborn as sns  # Importar seaborn para los gráficos

# %%
#| export
#| hide
from importlib.machinery import SourceFileLoader
core = SourceFileLoader("core",r"C:\Users\UFD\estadistica\estadistica\core.py").load_module()

from core import (calcular_media, calcular_mediana, calcular_desviacion_estandar, calcular_rango_intercuartil,
           graficar_histograma, graficar_caja_bigotes, graficar_dispersion)

# %%
#| export 
np.random.seed(42)
datos = np.random.normal(loc=50, scale=10, size=1000)
datos_x = np.random.rand(100)
datos_y = 2.5 * datos_x + np.random.normal(loc=0, scale=0.2, size=100)


media = calcular_media(datos)
mediana = calcular_mediana(datos)
desviacion_estandar = calcular_desviacion_estandar(datos)
rango_intercuartil = calcular_rango_intercuartil(datos)

# %%
print(f"Media: {media}")
print(f"Mediana: {mediana}")
print(f"Desviación Estándar: {desviacion_estandar}")
print(f"Rango Intercuartil: {rango_intercuartil}")
# Out:
# Media: 50.193320558223256
# Mediana: 50.25300612234888
# Desviación Estándar: 9.787262077473542
# Rango Intercuartil: 12.955341809352817

# %%
graficar_histograma(datos, titulo="Histograma")

# %%
graficar_caja_bigotes(datos, titulo="Caja y Bigotes")

# %%
graficar_dispersion(datos_x, datos_y, titulo="Diagrama de Dispersión", xlabel="X", ylabel="Y")
